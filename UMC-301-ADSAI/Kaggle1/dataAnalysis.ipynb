# %% [markdown]
# ### Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Train Data

# %%
# loading data as dataframe
df_train = pd.read_csv('train.csv')
print(df_train.head())
# Out:
#    id  song_duration_ms  acousticness  danceability    energy  \
# 0   0          212990.0      0.642286      0.856520  0.707073
# 1   1               NaN      0.054866      0.733289  0.835545
# 2   2          193213.0           NaN      0.188387  0.783524
# 3   3          249893.0      0.488660      0.585234  0.552685
# 4   4          165969.0      0.493017           NaN  0.740982
#
#    instrumentalness   key  liveness  loudness  audio_mode  speechiness  \
# 0          0.002001  10.0       NaN -5.619088           0     0.082570
# 1          0.000996   8.0  0.436428 -5.236965           1     0.127358
# 2         -0.002694   5.0  0.170499 -4.951759           0     0.052282
# 3          0.000608   0.0  0.094805 -7.893694           0     0.035618
# 4          0.002033  10.0  0.094891 -2.684095           0     0.050746
#
#         tempo  time_signature  audio_valence  song_popularity
# 0  158.386236               4       0.734642                0
# ...

# %%
# number of rows and columns
print(df_train.shape)
# Out:
# (30000, 15)

# %% [markdown]
# There are 30000 rows and 15 columns in the train dataset means 30000 samples and 14 features + 1 target variable.

# %% [markdown]
# ### Test Dataset

# %%
df_test = pd.read_csv('test.csv')
print(df_test.head())
# Out:
#    id  song_duration_ms  acousticness  danceability    energy  \
# 0   0               NaN      0.017907      0.660564  0.868227
# 1   1          164029.0      0.031120      0.419261  0.981707
# 2   2          167745.0      0.429844      0.729660  0.925064
# 3   3          184688.0      0.008413      0.731891  0.621494
# 4   4          169957.0      0.075292      0.637182  0.752561
#
#    instrumentalness  key  liveness  loudness  audio_mode  speechiness  \
# 0          0.002326  6.0  0.093276 -4.979164           0     0.287300
# 1          0.002073  6.0  0.393012       NaN           0     0.045645
# 2          0.003053  8.0  0.349517 -5.658771           1     0.052781
# 3         -0.001749  0.0  0.207743 -7.091666           1     0.051576
# 4         -0.001368  1.0  0.872533 -6.428241           0     0.034357
#
#         tempo  time_signature  audio_valence
# 0   91.465071               4       0.591148
# 1  103.987859               3       0.597878
# ...

# %%
print(df_test.shape)
# Out:
# (10000, 14)

# %% [markdown]
# There are 10000 rows and 15 columns in the train dataset means 10000 samples and 14 features

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = df_train.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ##### Clearly from correlation matrix, Popularity doesn't strongly correlate with any single musical feature, suggesting listener preference is multi-dimensional.
